# %% [markdown]
# <a href="https://colab.research.google.com/github/prithvi-2005/Projects/blob/main/CA_II_6211.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing all necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
#loading dataset
df=pd.read_csv('/content/Placement_Data_Full_Class.csv')

# %% [markdown]
# `df.head()` displays the first few rows of a DataFrame (tabular data) in Python, providing a quick overview of its contents.

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# `df.tail()` displays the last few rows of a DataFrame (df) to provide a quick overview of its data.

# %%
df.tail()
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p   hsc_b     hsc_s  degree_p  \
# 210    211      M   80.6   Others   82.0  Others  Commerce      77.6
# 211    212      M   58.0   Others   60.0  Others   Science      72.0
# 212    213      M   67.0   Others   67.0  Others  Commerce      73.0
# 213    214      F   74.0   Others   66.0  Others  Commerce      58.0
# 214    215      M   62.0  Central   58.0  Others   Science      53.0
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 213  Comm&Mgmt     No     70.0         Mkt&HR  60.23      Placed  204000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN

# %% [markdown]
# `df.isnull()` checks for missing (null) values in a DataFrame 'df' and returns a DataFrame of the same shape with 'True' where values are missing and 'False' where values are not missing.

# %%
null_values=df.isnull().sum()

print("Null values in the DataFrame: ")
print(null_values)
#This will print the null values for each row
# Out:
# Null values in the DataFrame:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %% [markdown]
# Inference
#
# There are 67 null values in our data, which means 67 unhired candidates.
# We can't drop these values as this will provide a valuable information on why candidates failed to get hired.
# We can't impute it with mean/median values and it will go against the context of this dataset and it will show unhired candidates got salary.
# Our best way to deal with these null values is to impute it with '0' which shows they don't have any income.

# %%
df['salary'].fillna(value=0, inplace=True)

# %%
df.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %% [markdown]
# We have dropped serial number as we have index as default and we have dropped the boards of school education as it doesn't matter for recruitment.

# %% [markdown]
# `df.drop` is a pandas DataFrame method used to remove specified rows or columns from the DataFrame.

# %%
df.drop(['sl_no','ssc_b','hsc_b'], axis = 1,inplace=True)
df.head()
# Out:
#   gender  ssc_p  hsc_p     hsc_s  degree_p   degree_t workex  etest_p  \
# 0      M  67.00  91.00  Commerce     58.00   Sci&Tech     No     55.0
# 1      M  79.33  78.33   Science     77.48   Sci&Tech    Yes     86.5
# 2      M  65.00  68.00      Arts     64.00  Comm&Mgmt     No     75.0
# 3      M  56.00  52.00   Science     52.00   Sci&Tech     No     66.0
# 4      M  85.80  73.60  Commerce     73.30  Comm&Mgmt     No     96.8
#
#   specialisation  mba_p      status    salary
# 0         Mkt&HR  58.80      Placed  270000.0
# 1        Mkt&Fin  66.28      Placed  200000.0
# 2        Mkt&Fin  57.80      Placed  250000.0
# 3         Mkt&HR  59.43  Not Placed       0.0
# 4        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# `df.shape` returns a tuple representing the dimensions (rows, columns) of a DataFrame `df`.

# %%
df.shape
# Out:
# (215, 12)

# %% [markdown]
# df.info() provides a concise summary of a Pandas DataFrame, including data types, non-null counts, and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          215 non-null    object
#  1   ssc_p           215 non-null    float64
#  2   hsc_p           215 non-null    float64
#  3   hsc_s           215 non-null    object
#  4   degree_p        215 non-null    float64
#  5   degree_t        215 non-null    object
#  6   workex          215 non-null    object
#  7   etest_p         215 non-null    float64
#  8   specialisation  215 non-null    object
#  9   mba_p           215 non-null    float64
#  10  status          215 non-null    object
#  11  salary          215 non-null    float64
# dtypes: float64(6), object(6)
# memory usage: 20.3+ KB

# %% [markdown]
# df.describe() provides summary statistics (count, mean, std, min, 25%, 50%, 75%, max) for each numerical column in a DataFrame 'df'.

# %%
df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     215.000000
# mean   198702.325581
# std    154780.926716
# min         0.000000
# 25%         0.000000
# 50%    240000.000000
# 75%    282500.000000
# max    940000.000000

# %% [markdown]
# We have checked for any duplicate values in the dataset,but their aren't any.

# %% [markdown]
# `df.duplicated()` in pandas checks for duplicated rows in a DataFrame, returning a boolean Series where True indicates a duplicated row.

# %%
df.duplicated().value_counts()
# Out:
# False    215
# dtype: int64

# %% [markdown]
#  df.columns returns the column labels or names of a DataFrame in pandas, representing the dataset's variables.

# %%
df.columns
# Out:
# Index(['gender', 'ssc_p', 'hsc_p', 'hsc_s', 'degree_p', 'degree_t', 'workex',
#        'etest_p', 'specialisation', 'mba_p', 'status', 'salary'],
#       dtype='object')

# %% [markdown]
# `df.value_counts()` returns a count of unique values in a DataFrame `df`.

# %%
df['gender'].value_counts()
# Out:
# M    139
# F     76
# Name: gender, dtype: int64

# %%
df['degree_t'].value_counts()
# Out:
# Comm&Mgmt    145
# Sci&Tech      59
# Others        11
# Name: degree_t, dtype: int64

# %%
df['specialisation'].value_counts()
# Out:
# Mkt&Fin    120
# Mkt&HR      95
# Name: specialisation, dtype: int64

# %% [markdown]
# `df.unique()` returns unique values in a DataFrame column or Series.

# %%
df['mba_p'].unique()
# Out:
# array([58.8 , 66.28, 57.8 , 59.43, 55.5 , 51.58, 53.29, 62.14, 61.29,
#        52.21, 60.85, 63.7 , 65.04, 68.63, 54.96, 64.66, 62.54, 67.28,
#        64.08, 77.89, 56.7 , 69.06, 68.81, 63.62, 74.01, 65.33, 57.55,
#        57.69, 64.15, 51.29, 58.32, 62.21, 72.78, 62.77, 62.74, 51.45,
#        55.47, 56.86, 62.56, 66.72, 69.76, 51.21, 62.9 , 69.7 , 66.53,
#        71.63, 54.55, 62.46, 56.11, 62.98, 62.65, 65.49, 71.04, 65.56,
#        52.71, 66.88, 63.59, 57.99, 56.66, 57.24, 62.48, 59.69, 59.5 ,
#        58.78, 57.1 , 58.46, 60.99, 59.24, 68.07, 65.45, 66.94, 68.53,
#        59.75, 67.2 , 67.  , 64.27, 57.65, 59.42, 67.99, 62.35, 70.2 ,
#        60.44, 66.69, 62.  , 76.18, 57.03, 59.08, 64.36, 62.36, 68.03,
#        62.79, 59.47, 55.41, 54.97, 62.16, 64.44, 69.03, 57.31, 64.95,
#        61.31, 65.83, 58.23, 55.3 , 65.69, 73.52, 58.31, 56.09, 54.8 ,
#        60.64, 53.94, 63.08, 55.01, 60.5 , 70.85, 67.05, 70.48, 64.34,
# ...

# %%
df['status'].unique()
# Out:
# array(['Placed', 'Not Placed'], dtype=object)

# %%
df['salary'].nunique()
# Out:
# 46

# %%
df['degree_t'].nunique()
# Out:
# 3

# %% [markdown]
# `df.groupby` is a pandas DataFrame method used to group data based on one or more columns, allowing for aggregation and analysis of subsets of the data.

# %%
df.groupby('degree_t').mean()
# Out:
# <ipython-input-23-0a882aa2b436>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('degree_t').mean()
#                ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# degree_t
# Comm&Mgmt  65.955586  67.185379  66.203103  71.985241  61.865379
# Others     64.227273  60.181818  60.666364  72.494545  61.374545
# Sci&Tech   71.189322  65.385593  67.844237  72.310508  63.461186
#
#                   salary
# degree_t
# Comm&Mgmt  196000.000000
# Others     127454.545455
# Sci&Tech   218627.118644

# %% [markdown]
# ```
#
# ```
# # UNIVARIATE ANALYSIS

# %% [markdown]
# A boxplot is a graphical representation of a dataset that displays its five-number summary: minimum, first quartile, median, third quartile, and maximum, helping to visualize its distribution and identify outliers.

# %%
plt.figure(figsize = (10, 10))
plt.style.use('seaborn-white')
ax=plt.subplot(221)
plt.boxplot(df['ssc_p'])
ax.set_title('Secondary school percentage')
ax=plt.subplot(222)
plt.boxplot(df['hsc_p'])
ax.set_title('Higher Secondary school percentage')
ax=plt.subplot(223)
plt.boxplot(df['degree_p'])
ax.set_title('UG Degree percentage')
ax=plt.subplot(224)
plt.boxplot(df['etest_p'])
ax.set_title('Employability percentage')
# Out:
# <ipython-input-24-8ddd47f87690>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
# Text(0.5, 1.0, 'Employability percentage')

# %% [markdown]
# Outliers are data points that significantly deviate from the majority of the data, potentially indicating errors or unusual phenomena.
# We have majority of outliers in hsc percentage.

# %% [markdown]
# # Count of Categorical Features-Count Plot

# %% [markdown]
# A countplot is a type of data visualization that displays the frequency of categorical data in a bar chart.

# %%
plt.figure(figsize = (110, 10))
plt.style.use('seaborn-white')

#Specialisation
plt.subplot(234)
ax=sns.countplot(x="specialisation", data=df, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("magma", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Work experience
plt.subplot(235)
ax=sns.countplot(x="workex", data=df, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("cividis", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Degree type
plt.subplot(233)
ax=sns.countplot(x="degree_t", data=df, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("viridis", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12,rotation=20)

#Gender
plt.subplot(231)
ax=sns.countplot(x="gender", data=df, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("hot", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Higher secondary specialisation
plt.subplot(232)
ax=sns.countplot(x="hsc_s", data=df, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("rocket", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)

#Status of recruitment
plt.subplot(236)
ax=sns.countplot(x="status", data=df, facecolor=(0, 0, 0, 0),
                 linewidth=5,edgecolor=sns.color_palette("copper", 3))
fig = plt.gcf()
fig.set_size_inches(10,10)
ax.set_xticklabels(ax.get_xticklabels(),fontsize=12)
# Out:
# <ipython-input-35-81ad2cc0c241>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')
# [Text(0, 0, 'Placed'), Text(1, 0, 'Not Placed')]

# %% [markdown]
# *   We have more male candidates than female
# *   We have candidates who did commerce as their hasc course as well as undergrad
# *   Science background candidates are the second  highest in the both the cases.
# *   Candidates from Marketing and Finance dual specialisation are high.
# *   Most of the candidates from as per the given dataset do not have work experience.
# *  Most of the candidates as per the given dataset got placed in a company.

# %% [markdown]
# # Distribution salary-Placed students

# %%
df['salary'].unique()
# Out:
# array([270000., 200000., 250000.,      0., 425000., 252000., 231000.,
#        260000., 218000., 300000., 236000., 265000., 393000., 360000.,
#        240000., 350000., 278000., 320000., 411000., 287000., 204000.,
#        450000., 216000., 220000., 268000., 275000., 336000., 230000.,
#        500000., 400000., 210000., 420000., 380000., 280000., 276000.,
#        940000., 225000., 233000., 690000., 340000., 255000., 285000.,
#        290000., 650000., 264000., 295000.])

# %% [markdown]
# `histplot` is a function used to create histograms, which display the distribution of data in a visual format.

# %%
plt.figure(figsize=(10, 6))
plt.hist(x='salary',data=df, bins=4, color='salmon', edgecolor='black')
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The above histogram of salary distribution of students who got placed is concentrated between (2L-4L PA).
# There are four bins in the histogram, indicating that the salaries are divided into four intervals.

# %% [markdown]
# # BIVARIATE ANALYSIS

# %% [markdown]
# #  MBA marks vs Placement Status- Does your academic score influence?

# %% [markdown]
# A boxplot summarizes the distribution of a dataset, showing median, quartiles, and outliers, while a swarmplot displays individual data points, revealing their distribution.

# %%
g = sns.boxplot(y = "status",x = 'mba_p',data=df)
g = sns.swarmplot(y = "status",x = 'mba_p',data=df, size = 7,color = 'black')
g.figure.set_size_inches(12,8)
plt.show()

# %% [markdown]
# Comparitively there's a slight difference between the percentage scores between both the groups, But still placed candidates still has an upper hand when it comes to numbers as you can see in the swarm. So as per the plot,percentage do influence the placement status

# %% [markdown]
# # Work experience Vs Placement Status

# %% [markdown]
# A pie chart is a circular graph that visually represents data proportions using slices, with each slice representing a different category's percentage of the whole.

# %%
plt.style.use('seaborn-white')
f,ax=plt.subplots(1,2,figsize=(18,8))
df['workex'].value_counts().plot.pie(explode=[0,0.05],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Work experience')
sns.countplot(x = 'workex',hue = "status",data = df)
ax[1].set_title('Influence of experience on placement')
plt.show()
# Out:
# <ipython-input-32-4968618d7bae>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-white')

# %% [markdown]
# * We have nearly 66.2% of candidates who never had any wrok experience
# * Candidates who never had work experience have got hired more than the ones who had experience.
# * We can conclude that work experience doen't influence a candidate in the recruitment process.

# %% [markdown]
# A scatter plot is a graphical representation of data points on a two-dimensional plane to show the relationship or distribution between two variables.

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='mba_p', y='etest_p',hue="workex", data=df, color='skyblue')
plt.title("Scatter Plot:Realtion between MBA percentage and Employabaility score")
plt.xlabel("MBA Percentage")
plt.ylabel("Employability Test Scores")
plt.show()

# %% [markdown]
# * There is no relation between mba percentage and employability test.
# * There are many candidates who haven't got placed when they don't have work experience.
# * Most of the candidates who performed better in both tests have got placed

# %% [markdown]
# A scatter plot is a graphical representation of data points on a two-dimensional plane to show the relationship or distribution between two variables.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df,y='salary',x='specialisation',hue='gender',ci=None,palette='Set2')
plt.title('Gender bias while offering remuneration')
plt.show()
# Out:
# <ipython-input-47-fc1bc9e44a22>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=df,y='salary',x='specialisation',hue='gender',ci=None,palette='Set2')

# %% [markdown]
# * The top salaries were given to male.
# * The average salary offered were also higher for male.
# * More male candidates were placed compared to female candidates.

# %% [markdown]
# df.corr() computes the correlation between all numerical columns in the DataFrame. It's useful to understand relationships between variables.

# %%
df.corr()
# Out:
# <ipython-input-33-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# # Correlation between academic percentages

# %% [markdown]
# A heatmap is a visual representation of data where colors indicate values, helping to reveal patterns or trends.

# %%
sns.heatmap(df.corr(),annot=True,fmt='.1g',cmap='viridis')
# Out:
# <ipython-input-39-839de8ce2689>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,fmt='.1g',cmap='viridis')
# <Axes: >

# %% [markdown]
# * Candidates who were good in their academics performed well throughout school,undergrad,mba and even employability test.
# * These percentages dont have influence over their salary.

# %% [markdown]
# # MULTIVARIATE ANALYSIS

# %% [markdown]
# A pairplot is a data visualization technique that displays scatterplots and histograms for all possible pairs of variables in a dataset, helping to visualize relationships and distributions.

# %%
sns.pairplot(df,vars=['ssc_p','hsc_p','degree_p','mba_p','etest_p'],hue="status")

# %% [markdown]
# * Candidates who have high score in higher secondary and undergrad got placed.
# * Whomever got high scores in their schools got placed.
# * Comparing the number of students who got placed candidates who got good mbs percentage and employability percentage.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# From the analysis report on campus recruitment dataset here are my following conclusions :
#
# *   **Educational percentages** are highly influential for a candidate to get placed.
# *   **Past Work Experience** doesn't influence much on your masters final placements.
# *   There is no **gender discrimination** while hiring,but overall higher packages were given to male.
# *   Academic percentages have no relation towards salary package.
